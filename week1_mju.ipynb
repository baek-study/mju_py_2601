# %% [markdown]
# <a href="https://colab.research.google.com/github/baek-study/mju_py_2601/blob/main/week1_mju.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 명지대학교, baekhj@gmail.com <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**🚀 함께 미션: 첫 파이썬 코드 (Hello World!)**
#
# *   환영합니다! 여러분의 첫 파이썬 실습을 위한 공간입니다.
# *   다음 미션들을 순서대로 수행해 보도록 합시다.

# %% [markdown]
# ## **1. 코드 셀: 인사하기**
#
#
# * 코드 셀 추가: + 코드 버튼 클릭
# * 코드 입력: print("Hello World") 입력
# * 실행 버튼  누르기

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## **2. 코드 셀: 이름쓰기**
# * 코드 셀 추가: + 코드 버튼 클릭
# * 코드 입력: print(＂자신이름") 입력
# * 실행 단축키 : ctrl + enter 누르기

# %%
print('mju')
# Out:
# mju

# %% [markdown]
# ## **3. 텍스트: 마크다운**
# * 텍스트 추가: + 텍스트 버튼 클릭
# * 큰글씨 입력: # 자신 이름
# * 중간글씨 입력: ## 파이썬은 재미있다

# %% [markdown]
# # **mju**
# ##  *파이썬은 재미있다*

# %% [markdown]
# ## **4. 실행: 마법의 그래프**
#
#
# *   "파이썬은 쉽다" - 코드 몇줄에 그래프가!!!

# %%
import matplotlib.pyplot as plt

# 1. 간단한 데이터 준비
x = [1, 2, 3, 4, 5]
y = [10, 25, 15, 30, 20]

# 2. 그래프 그리기 설정
plt.plot(x, y)

# 3. 그래프 제목 달기
plt.title("My First Graph by mju ")

# 4. 화면에 출력
plt.show()
